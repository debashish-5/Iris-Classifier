# %%
import pandas as pd
from sklearn.ensemble import RandomForestClassifier
#loading the data from excel
data = pd.read_excel("iris-train.xlsx")
#taking feature from this train data 
feature = data.iloc[:,:-1]
#taking labels from this train data 
labels = data.iloc[:,-1]
#loading RandomForestClassifier into model
print('WELCOME to MY ML WORLD!')
print('(O<_>O) PLEASE enter the DATA')
model = RandomForestClassifier()
model.fit(feature.values,labels.values)
sepallength = float(input('sepallength: '))
sepalwidth = float(input('sepalwidth: '))
petallength = float(input('petallength: '))
petalwidth = float(input('petalwidth: '))
# The model expects a 2D array for prediction
features = [[sepallength, sepalwidth, petallength, petalwidth]]
prediction = model.predict(features)
print(f'[o_o] class : {prediction[0]}')
# Out:
# WELCOME to MY ML WORLD!
# (O<_>O) PLEASE enter the DATA
# sepallength:  5.4
# sepalwidth:  3.4
# petallength:  1.7
# petalwidth:  0.2
# [o_o] class : Iris-setosa
